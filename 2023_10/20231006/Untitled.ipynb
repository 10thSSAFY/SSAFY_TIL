# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

csv_path = 'austin_weather.csv'
df = pd.read_csv(csv_path)
df
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0     2013-12-21         74        60        45            67           49
# 1     2013-12-22         56        48        39            43           36
# 2     2013-12-23         58        45        32            31           27
# 3     2013-12-24         61        46        31            36           28
# 4     2013-12-25         58        50        41            44           40
# ...          ...        ...       ...       ...           ...          ...
# 1314  2017-07-27        103        89        75            71           67
# 1315  2017-07-28        105        91        76            71           64
# 1316  2017-07-29        107        92        77            72           64
# 1317  2017-07-30        106        93        79            70           68
# 1318  2017-07-31         99        88        77            66           61
#
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month

# %%
df_mean = df.groupby(['Year', 'Month'])[["TempHighF", "TempAvgF", "TempLowF"]].mean()
df_mean
# Out:
#              TempHighF   TempAvgF   TempLowF
# Year Month
# 2013 12      59.000000  48.818182  38.090909
# 2014 1       63.612903  50.870968  37.612903
#      2       66.464286  55.178571  43.321429
#      3       70.612903  59.064516  47.096774
#      4       79.833333  69.400000  58.566667
#      5       85.419355  74.806452  63.709677
#      6       90.966667  82.700000  73.066667
#      7       95.193548  84.580645  73.580645
#      8       99.032258  87.354839  75.258065
#      9       90.500000  80.800000  70.733333
#      10      84.903226  74.741935  64.032258
#      11      66.000000  55.966667  45.366667
#      12      62.774194  55.322581  47.322581
# 2015 1       58.322581  48.935484  39.000000
#      2       61.642857  51.607143  40.892857
#      3       70.032258  60.483871  50.548387
#      4       80.600000  71.433333  61.766667
#      5       83.419355  75.419355  66.935484
#      6       90.233333  81.333333  71.866667
#      7       95.677419  85.838710  75.483871
# ...

# %%
df_mean['TempHighF']
# Out:
# Year  Month
# 2013  12        59.000000
# 2014  1         63.612903
#       2         66.464286
#       3         70.612903
#       4         79.833333
#       5         85.419355
#       6         90.966667
#       7         95.193548
#       8         99.032258
#       9         90.500000
#       10        84.903226
#       11        66.000000
#       12        62.774194
# 2015  1         58.322581
#       2         61.642857
#       3         70.032258
#       4         80.600000
#       5         83.419355
#       6         90.233333
#       7         95.677419
#       8         99.354839
#       9         95.100000
#       10        86.193548
#       11        70.266667
#       12        68.451613
# 2016  1         62.967742
#       2         71.655172
#       3         76.548387
#       4         80.566667
#       5         83.193548
#       6         92.866667
#       7         98.935484
#       8         93.580645
#       9         92.433333
#       10        87.258065
# ...

# %%
csv_path = 'austin_weather.csv'
df = pd.read_csv(csv_path)
df = df[['Date', 'TempHighF', 'TempAvgF', 'TempLowF']]
# df

df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')
df['Monthly'] = df['Date'].dt.to_period('M')
# df
df_mean = df.groupby('Monthly')[["TempHighF", "TempAvgF", "TempLowF"]].mean()
df_mean['Monthly'] = df_mean.index

df_mean['Monthly']

# import matplotlib.pyplot as plt

# x = df_mean['Monthly']
# y_h = df_mean['TempHighF']
# plt.plot(x, y_h, label='High Temperature')

# y_a = df_mean['TempAvgF']
# plt.plot(x, y_a, label='Average Temperature')

# y_l = df_mean['TempLowF']
# plt.plot(x, y_l, label='Low Temperature')
# plt.legend()

# plt.title("Temperature Variation")
# plt.ylabel('Temperature (Fahrenheit)')
# plt.xlabel('Date')

# plt.grid(True)
# plt.show()
# Out:
# Monthly
# 2013-12    2013-12
# 2014-01    2014-01
# 2014-02    2014-02
# 2014-03    2014-03
# 2014-04    2014-04
# 2014-05    2014-05
# 2014-06    2014-06
# 2014-07    2014-07
# 2014-08    2014-08
# 2014-09    2014-09
# 2014-10    2014-10
# 2014-11    2014-11
# 2014-12    2014-12
# 2015-01    2015-01
# 2015-02    2015-02
# 2015-03    2015-03
# 2015-04    2015-04
# 2015-05    2015-05
# 2015-06    2015-06
# 2015-07    2015-07
# 2015-08    2015-08
# 2015-09    2015-09
# 2015-10    2015-10
# 2015-11    2015-11
# 2015-12    2015-12
# 2016-01    2016-01
# 2016-02    2016-02
# 2016-03    2016-03
# 2016-04    2016-04
# 2016-05    2016-05
# 2016-06    2016-06
# 2016-07    2016-07
# 2016-08    2016-08
# 2016-09    2016-09
# 2016-10    2016-10
# 2016-11    2016-11
# 2016-12    2016-12
# 2017-01    2017-01
# 2017-02    2017-02
# 2017-03    2017-03
# 2017-04    2017-04
# 2017-05    2017-05
# 2017-06    2017-06
# 2017-07    2017-07
# Freq: M, Name: Monthly, dtype: period[M]

# %%
csv_path = 'austin_weather.csv'
df = pd.read_csv(csv_path)
df['Events'] = df['Events'].replace(' ', 'No Events')
df = df[['Date', 'Events']]

data = df.Events.str.split(' , ')
df = pd.DataFrame(data = data)

df = df.explode('Events')
df.astype('str')
df = df['Events'].value_counts()

# print(df.index)
# print(df.values)

plt.bar(df.index, df.values)
plt.grid()

# plt.show()
