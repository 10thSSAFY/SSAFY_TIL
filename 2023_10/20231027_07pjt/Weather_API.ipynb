# %%
import requests
api_key = '98d2977b65c056f16868e7db9d287b84'
city = "Seoul,KR"
url = f'http://api.openweathermap.org/data/2.5/forecast?q={city}&appid={api_key}'
response = requests.get(url).json()

print(response)
# Out:
# {'cod': '200', 'message': 0, 'cnt': 40, 'list': [{'dt': 1698375600, 'main': {'temp': 288.96, 'feels_like': 288.45, 'temp_min': 288.96, 'temp_max': 291.08, 'pressure': 1015, 'sea_level': 1015, 'grnd_level': 1008, 'humidity': 71, 'temp_kf': -2.12}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'clouds': {'all': 59}, 'wind': {'speed': 2.07, 'deg': 41, 'gust': 2.89}, 'visibility': 10000, 'pop': 0.04, 'sys': {'pod': 'd'}, 'dt_txt': '2023-10-27 03:00:00'}, {'dt': 1698386400, 'main': {'temp': 290.99, 'feels_like': 290.29, 'temp_min': 290.99, 'temp_max': 292.53, 'pressure': 1014, 'sea_level': 1014, 'grnd_level': 1007, 'humidity': 56, 'temp_kf': -1.54}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'clouds': {'all': 39}, 'wind': {'speed': 1.35, 'deg': 7, 'gust': 2.48}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2023-10-27 06:00:00'}, {'dt': 1698397200, 'main': {'temp': 291.24, 'fee
# ...

# %%
import pprint

# %%
pprint.pprint(response.get('list'))
# Out:
# [{'clouds': {'all': 59},
#   'dt': 1698375600,
#   'dt_txt': '2023-10-27 03:00:00',
#   'main': {'feels_like': 288.45,
#            'grnd_level': 1008,
#            'humidity': 71,
#            'pressure': 1015,
#            'sea_level': 1015,
#            'temp': 288.96,
#            'temp_kf': -2.12,
#            'temp_max': 291.08,
#            'temp_min': 288.96},
#   'pop': 0.04,
#   'sys': {'pod': 'd'},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 41, 'gust': 2.89, 'speed': 2.07}},
#  {'clouds': {'all': 39},
#   'dt': 1698386400,
#   'dt_txt': '2023-10-27 06:00:00',
#   'main': {'feels_like': 290.29,
#            'grnd_level': 1007,
#            'humidity': 56,
#            'pressure': 1014,
#            'sea_level': 1014,
#            'temp': 290.99,
#            'temp_kf': -1.54,
#            'temp_max': 292.53,
# ...

# %%
import sys
sys.stdout = open('api.txt', 'w')

print(response)
